# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
print(sys.path)
import time

# %%
df=pd.read_csv("./data/collaborative filtering/survey_results_public.csv")
print(df.describe())
print(df.head())
print(df.columns)

n_row=df.shape[0]
print(df.isnull().sum()/n_row)
attr_to_drop=[]
attr_to_drop.append("SurveyTooLong")
attr_to_drop.append('SurveyEasy')
attr_to_drop.append("AdBlocker")
attr_to_drop.append("AdBlockerDisable")
attr_to_drop.append("AdBlockerReasons")
attr_to_drop.append("AdsAgreeDisagree1")
attr_to_drop.append("AdsAgreeDisagree2")
attr_to_drop.append("AdsAgreeDisagree3")
attr_to_drop.append("AdsActions")
attr_to_drop.append("AdsPriorities1")
attr_to_drop.append("AdsPriorities2")
attr_to_drop.append("AdsPriorities3")
attr_to_drop.append("AdsPriorities4")
attr_to_drop.append("AdsPriorities5")
attr_to_drop.append("AdsPriorities6")
attr_to_drop.append("AdsPriorities7")
attr_to_drop.append("AIDangerous")
attr_to_drop.append("AIInteresting")
attr_to_drop.append("AIResponsible")
attr_to_drop.append("AIFuture")
attr_to_drop.append("EthicsChoice")
attr_to_drop.append("EthicsReport")
attr_to_drop.append("EthicsResponsible")
attr_to_drop.append("EthicsImplications")
attr_to_drop.append("EthicsChoice")
attr_to_drop.append("StackOverflowRecommend")
attr_to_drop.append("StackOverflowVisit")
attr_to_drop.append("StackOverflowHasAccount")
attr_to_drop.append("StackOverflowParticipate")
attr_to_drop.append("StackOverflowJobs")
attr_to_drop.append("StackOverflowDevStory")
attr_to_drop.append("StackOverflowJobsRecommend")
attr_to_drop.append("StackOverflowConsiderMember")
attr_to_drop.append("HypotheticalTools1")
attr_to_drop.append("HypotheticalTools2")
attr_to_drop.append("HypotheticalTools3")
attr_to_drop.append("HypotheticalTools4")
attr_to_drop.append("HypotheticalTools5")
attr_to_drop.append("JobContactPriorities1")
attr_to_drop.append("JobContactPriorities2")
attr_to_drop.append("JobContactPriorities3")
attr_to_drop.append("JobContactPriorities4")
attr_to_drop.append("JobContactPriorities5")
attr_to_drop.append("TimeAfterBootcamp")
df=df.drop(df.columns[[126,3,8,15,50,51,53,62,63,64,123,125,43,44,45,46,47,48,49]],axis=1)
print(df.columns)
df=df[df.columns.difference(attr_to_drop)]
print(df.head())
attr_to_drop=["HackathonReasons","ErgonomicDevices"]
df=df[df.columns.difference(attr_to_drop)]


print(sum(df.isnull().sum())/float(np.prod(df.shape)))
col_null=df.isnull().sum()/n_row
print(col_null.sort_values(ascending=False))
#print(sum(df.isnull().sum()))

# %%
#New set of attributes to be removed
attr_to_drop=['Hobby','NumberMonitors','Salary','CheckInCode','WakeTime','TimeFullyProductive','SkipMeals','SexualOrientation','HoursOutside','Exercise','EthicalImplications','EducationParents']
print(len(df.columns))
df=df[df.columns.difference(attr_to_drop)]
print(len(df.columns))
# Out:
# 66
# 54

# %%
#df.to_csv("removed2.csv")
import numpy as np
df1 = df.replace(np.nan, '', regex=True)

# %%
#find the unique values in each categorical attribute
Frameworknextyear=list()
for value in df1["FrameworkDesireNextYear"]:
        new=value.split(';')
        for i in new:
            Frameworknextyear.append(i)
sFNY=set(Frameworknextyear)
FrameworkWorkedWith=list()
for value in df1["FrameworkWorkedWith"]:
        new=value.split(';')
        for i in new:
            FrameworkWorkedWith.append(i)
sFW=set(FrameworkWorkedWith)
PlatformDesireNextYear=list()
for value in df1["PlatformDesireNextYear"]:
        new=value.split(';')
        for i in new:
            PlatformDesireNextYear.append(i)
sPDNY=set(PlatformDesireNextYear)
PlatformWorkedWith=list()
for value in df1["PlatformWorkedWith"]:
        new=value.split(';')
        for i in new:
            PlatformWorkedWith.append(i)
sPWW=set(PlatformWorkedWith)
LanguageDesireNextYear=list()
for value in df1["LanguageDesireNextYear"]:
        new=value.split(';')
        for i in new:
            LanguageDesireNextYear.append(i)
sLDNY=set(LanguageDesireNextYear)
LanguageWorkedWith=list()
for value in df1["LanguageWorkedWith"]:
        new=value.split(';')
        for i in new:
            LanguageWorkedWith.append(i)
sLWW=set(LanguageWorkedWith)
         
CommunicationTools=list()
for value in df1["CommunicationTools"]:
        new=value.split(';')
        for i in new:
            CommunicationTools.append(i)
sCT=set(CommunicationTools)

DatabaseWorkedWith=list()
for value in df1["DatabaseWorkedWith"]:
        new=value.split(';')
        for i in new:
            DatabaseWorkedWith.append(i)
sDWW=set(DatabaseWorkedWith)

DatabaseDesireNextYear=list()
for value in df1["DatabaseDesireNextYear"]:
        new=value.split(';')
        for i in new:
            DatabaseDesireNextYear.append(i)
sDNY=set(DatabaseDesireNextYear)

DevType=list()
for value in df1["DevType"]:
        new=value.split(';')
        for i in new:
            DevType.append(i)
sDT=set(DevType)
sFNY.remove("")
sFW.remove("")
sPDNY.remove("")
sPWW.remove("")
sLDNY.remove("")
sLWW.remove("")
sCT.remove("")
sDWW.remove("")
sDNY.remove("")
sDT.remove("")
print(sFNY)
print(sFW)
print(sPDNY)
print(sPWW)
print(sLDNY)
print(sLWW)
print(sCT)
print(sDWW)
print(sDNY)
print(sDT)
# Out:
# {'React', 'Xamarin', 'Cordova', 'Node.js', 'Django', '.NET Core', 'TensorFlow', 'Hadoop', 'Torch/PyTorch', 'Spring', 'Spark', 'Angular'}
# {'React', 'Xamarin', 'Cordova', 'Node.js', 'Django', '.NET Core', 'TensorFlow', 'Hadoop', 'Torch/PyTorch', 'Spring', 'Spark', 'Angular'}
# {'Mac OS', 'Windows Phone', 'Linux', 'Serverless', 'Drupal', 'iOS', 'SharePoint', 'Gaming console', 'Windows Desktop or Server', 'IBM Cloud or Watson', 'Predix', 'Azure', 'Apple Watch or Apple TV', 'Heroku', 'Arduino', 'AWS', 'Android', 'Amazon Echo', 'Google Cloud Platform/App Engine', 'ESP8266', 'Raspberry Pi', 'Mainframe', 'Firebase', 'Salesforce', 'WordPress', 'Google Home'}
# {'Mac OS', 'Windows Phone', 'Linux', 'Serverless', 'Drupal', 'iOS', 'SharePoint', 'Gaming console', 'Windows Desktop or Server', 'IBM Cloud or Watson', 'Predix', 'Azure', 'Apple Watch or Apple TV', 'Heroku', 'Arduino', 'AWS', 'Android', 'Amazon Echo', 'Google Cloud Platform/App Engine', 'ESP8266', 'Raspberry Pi', 'Mainframe', 'Firebase', 'Salesforce', 'WordPress', 'Google Home'}
# {'Visual Basic 6', 'C++', 'TypeScript', 'Python', 'Groovy', 'Perl', 'Rust', 'Go', 'Erlang', 'VBA', 'Matlab', 'Objective-C', 'Java', 'Scala', 'Julia', 'Bash/Shell', 'C', 'Delphi/Object Pascal', 'Cobol', 'SQL', 'C#', 'Ocaml', 'JavaScript', 'Lua', 'F#', 'Haskell', 'Kotlin', 'HTML', 'CSS', 'PHP', 'Ruby', 'R', 'Swift', 'CoffeeScript', 'Assembly', 'Clojure', 'VB.NET', 'Hack'}
# {'Visual Basic 6', 'C++', 'TypeScript', 'Python', 'Groovy', 'Perl', 'Rust', 'Go', 'Erlang', 'VBA', 'Matlab', 'Objective-C', 'Java', 'Scala', 'Julia', 'Bash/Shell', 'C', 'Delphi/Object Pascal', 'Cobol', 'SQL', 'C#', 'Lua', 'JavaScript', 'Ocaml', 'F#', 'Haskell', 'Kotlin', 'HTML', 'CSS', 'PHP', 'Ruby', 'R', 'Swift', 'CoffeeScript', 'Assembly', 'Clojure', 'VB.NET', 'Hack'}
# {'Other wiki tool (Github, Google Sites, proprietary software, etc.)', 'Confluence', 'Facebook', 'Other chat system (IRC, proprietary software, etc.)', 'Office / productivity suite (Microsoft Office, Google Suite, etc.)', 'Jira', 'Slack', 'Trello', 'HipChat', 'Stack Overflow Enterprise', 'Google Hangouts/Chat'}
# {'MariaDB', 'PostgreSQL', 'Redis', 'Amazon DynamoDB', 'SQL Server', 'Cassandra', 'Google Cloud Storage', 'MongoDB', 'Elasticsearch', 'Amazon RDS/Aurora', 'Neo4j', 'IBM Db2', 'Apache Hive', 'Google BigQuery', 'SQLite', 'Oracle', 'Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'MySQL', 'Memcached', 'Amazon Redshift', 'Apache HBase'}
# {'MariaDB', 'PostgreSQL', 'Redis', 'Amazon DynamoDB', 'SQL Server', 'Cassandra', 'Google Cloud Storage', 'MongoDB', 'Elasticsearch', 'Amazon RDS/Aurora', 'Neo4j', 'IBM Db2', 'Apache Hive', 'Google BigQuery', 'SQLite', 'Oracle', 'Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'MySQL', 'Memcached', 'Amazon Redshift', 'Apache HBase'}
# {'Student', 'Embedded applications or devices developer', 'Full-stack developer', 'QA or test developer', 'Desktop or enterprise applications developer', 'DevOps specialist', 'Mobile developer', 'Back-end developer', 'Database administrator', 'Engineering manager', 'Front-end developer', 'Game or graphics developer', 'Designer', 'System administrator', 'Data scientist or machine learning specialist', 'Data or business analyst', 'Educator or academic researcher', 'Marketing or sales professional', 'C-suite executive (CEO, CTO, etc.)', 'Product manager'}

# %%
#converted categorical variables into numerical
from sklearn.preprocessing import LabelEncoder
print(set(df1['JobSatisfaction']))
number=LabelEncoder()
df1['CareerSatisfaction']=number.fit_transform(df1['CareerSatisfaction'])
df1['Employment']=number.fit_transform(df1['Employment'])
df1['FormalEducation']=number.fit_transform(df1['FormalEducation'])
df1['Gender']=number.fit_transform(df1['Gender'])
df1['HopeFiveYears']=number.fit_transform(df1['HopeFiveYears'])
df1['HoursComputer']=number.fit_transform(df1['HoursComputer'])
df1['JobSatisfaction']=number.fit_transform(df1['JobSatisfaction'])
df1['OpenSource']=number.fit_transform(df1['OpenSource'])
df1['OperatingSystem']=number.fit_transform(df1['OperatingSystem'])
df1['Student']=number.fit_transform(df1['Student'])
df1['UndergradMajor']=number.fit_transform(df1['UndergradMajor'])
df1['YearsCoding']=number.fit_transform(df1['YearsCoding'])
df1['YearsCodingProf']=number.fit_transform(df1['YearsCodingProf'])

#df1.to_csv("./data/user_preprocessing/categoricalconverted.csv")
# Out:
# {'Extremely satisfied', 'Neither satisfied nor dissatisfied', '', 'Moderately dissatisfied', 'Slightly satisfied', 'Extremely dissatisfied', 'Moderately satisfied', 'Slightly dissatisfied'}

# %%
#sFNY.add('Respondent')
#Create a separate dataframe based on one hot encoding for the attributes.
# Framework=pd.DataFrame(columns=sFNY)
# idx=0
# Framework.insert(loc=idx,column='Respondent', value=[0])
# #print(Framework.columns)
# print(Framework.shape[0])
# coldic=dict(zip(Framework.columns,range(0,13)))
# print(coldic)
# #print(df1.columns)
# print(df1.shape[0])
# for i in range(3):
#     Framework = Framework.append({}, ignore_index=True)
FrameworkWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sFW:
    
    FrameworkWorkedWith[i]=""
PlatformWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sPWW:
    print(i)
    PlatformWorkedWith[i]=""
LanguageWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sLWW:
    LanguageWorkedWith[i]=""
DatabaseWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sDWW:
    DatabaseWorkedWith[i]=""
DevType = pd.DataFrame(df1['Respondent'])
for i in sDT:
    DevType[i]=""
#framework.to_csv("framework.csv")
#framework.resize=[[98855,,len(sFNY)]]
print(len(sFW))
print(len(sPWW))
# Out:
# Mac OS
# Windows Phone
# Linux
# Serverless
# Drupal
# iOS
# SharePoint
# Gaming console
# Windows Desktop or Server
# IBM Cloud or Watson
# Predix
# Azure
# Apple Watch or Apple TV
# Heroku
# Arduino
# AWS
# Android
# Amazon Echo
# Google Cloud Platform/App Engine
# ESP8266
# Raspberry Pi
# Mainframe
# Firebase
# Salesforce
# WordPress
# Google Home
# 12
# 26

# %%
# print(Framework.shape[0])
# Framework.to_csv("hello1.csv")


time_start=time.time()
coldic=dict(zip(FrameworkWorkedWith.columns,range(0,len(sFW)+1)))
print(coldic)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'FrameworkWorkedWith']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            FrameworkWorkedWith.iloc[i,coldic[value]]=1
time_end=time.time()
print(time_end-time_start)
# Out:
# {'Respondent': 0, 'React': 1, 'Xamarin': 2, 'Cordova': 3, 'Node.js': 4, 'Django': 5, '.NET Core': 6, 'TensorFlow': 7, 'Hadoop': 8, 'Torch/PyTorch': 9, 'Spring': 10, 'Spark': 11, 'Angular': 12}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# 780.4256777763367

# %%
FrameworkDesireNextYear = pd.DataFrame(df1['Respondent'])
for i in sFNY:
    
    FrameworkDesireNextYear[i]=""
time_start=time.time()
coldic=dict(zip(FrameworkDesireNextYear.columns,range(0,len(sFNY)+1)))
print(coldic)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'FrameworkDesireNextYear']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            FrameworkDesireNextYear.iloc[i,coldic[value]]=1
time_end=time.time()
print(time_end-time_start)
# Out:
# {'Respondent': 0, 'React': 1, 'Xamarin': 2, 'Cordova': 3, 'Node.js': 4, 'Django': 5, '.NET Core': 6, 'TensorFlow': 7, 'Hadoop': 8, 'Torch/PyTorch': 9, 'Spring': 10, 'Spark': 11, 'Angular': 12}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# 1072.0754425525665

# %%
PlatformDesireNextYear = pd.DataFrame(df1['Respondent'])
for i in sPDNY:
    
    PlatformDesireNextYear[i]=""
time_start=time.time()
coldic=dict(zip(PlatformDesireNextYear.columns,range(0,len(sPDNY)+1)))
print(coldic)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'PlatformDesireNextYear']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            PlatformDesireNextYear.iloc[i,coldic[value]]=1
time_end=time.time()
print(time_end-time_start)
# Out:
# {'Respondent': 0, 'Mac OS': 1, 'Windows Phone': 2, 'Linux': 3, 'Serverless': 4, 'Drupal': 5, 'iOS': 6, 'SharePoint': 7, 'Gaming console': 8, 'Windows Desktop or Server': 9, 'IBM Cloud or Watson': 10, 'Predix': 11, 'Azure': 12, 'Apple Watch or Apple TV': 13, 'Heroku': 14, 'Arduino': 15, 'AWS': 16, 'Android': 17, 'Amazon Echo': 18, 'Google Cloud Platform/App Engine': 19, 'ESP8266': 20, 'Raspberry Pi': 21, 'Mainframe': 22, 'Firebase': 23, 'Salesforce': 24, 'WordPress': 25, 'Google Home': 26}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# 1501.1580307483673

# %%
LanguageDesireNextYear = pd.DataFrame(df1['Respondent'])
for i in sLDNY:
    
    LanguageDesireNextYear[i]=""
time_start=time.time()
coldic=dict(zip(LanguageDesireNextYear.columns,range(0,len(sLDNY)+1)))
print(coldic)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'LanguageDesireNextYear']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            LanguageDesireNextYear.iloc[i,coldic[value]]=1
time_end=time.time()
print(time_end-time_start)
# Out:
# {'Respondent': 0, 'Visual Basic 6': 1, 'C++': 2, 'TypeScript': 3, 'Python': 4, 'Groovy': 5, 'Perl': 6, 'Rust': 7, 'Go': 8, 'Erlang': 9, 'VBA': 10, 'Matlab': 11, 'Objective-C': 12, 'Java': 13, 'Scala': 14, 'Julia': 15, 'Bash/Shell': 16, 'C': 17, 'Delphi/Object Pascal': 18, 'Cobol': 19, 'SQL': 20, 'C#': 21, 'Ocaml': 22, 'JavaScript': 23, 'Lua': 24, 'F#': 25, 'Haskell': 26, 'Kotlin': 27, 'HTML': 28, 'CSS': 29, 'PHP': 30, 'Ruby': 31, 'R': 32, 'Swift': 33, 'CoffeeScript': 34, 'Assembly': 35, 'Clojure': 36, 'VB.NET': 37, 'Hack': 38}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# 2735.35924077034

# %%
DatabaseDesireNextYear = pd.DataFrame(df1['Respondent'])
for i in sDNY:
    
    DatabaseDesireNextYear[i]=""
time_start=time.time()
coldic=dict(zip(DatabaseDesireNextYear.columns,range(0,len(sDNY)+1)))
print(coldic)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'DatabaseDesireNextYear']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            DatabaseDesireNextYear.iloc[i,coldic[value]]=1
time_end=time.time()
print(time_end-time_start)
# Out:
# {'Respondent': 0, 'MariaDB': 1, 'PostgreSQL': 2, 'Redis': 3, 'Amazon DynamoDB': 4, 'SQL Server': 5, 'Cassandra': 6, 'Google Cloud Storage': 7, 'MongoDB': 8, 'Elasticsearch': 9, 'Amazon RDS/Aurora': 10, 'Neo4j': 11, 'IBM Db2': 12, 'Apache Hive': 13, 'Google BigQuery': 14, 'SQLite': 15, 'Oracle': 16, 'Microsoft Azure (Tables, CosmosDB, SQL, etc)': 17, 'MySQL': 18, 'Memcached': 19, 'Amazon Redshift': 20, 'Apache HBase': 21}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# 1350.2758250236511

# %%
# FrameworkDesireNextYear.to_csv("./data/collaborative filtering/FrameworkDesireNextYear.csv")
# PlatformDesireNextYear.to_csv("./data/collaborative filtering/PlatformDesireNextYear.csv")
# DatabaseDesireNextYear.to_csv("./data/collaborative filtering/DatabaseDesireNextYear.csv")
# LanguageDesireNextYear.to_csv("./data/collaborative filtering/LanguageDesireNextYear.csv")
